# %% [markdown]
# Recipe one: Working with APIS
#
# APIs (Appliation Program Interfaces) are an essential tool in data analysis. They can allow you to get updated streams of data to work with or access tools which you might not be able to run on your machine. They work by sending out a request to a server with specific parameters called a query. This query is then processed by the server and a response is provided to the machine which sent out that query. responses can be sent in a variety of formats, the most common of which is JSON, a file format which organizes data as an object from which the user can access attributes.

# %% [markdown]
# To demostrate working with an API, we will be using using the requests package, which streamlines requesting from APIs in a python environment.

# %%
import requests
import pandas as pd
import json

# %% [markdown]
# As an example of both getting data from an api, and using an api as a tool for computation that I would not be able to do locally, I will request from the google directions api to get the directions from Walla Walla to Portland Oregon

# %% [markdown]
# ### Important: do not store your API key directly in you code, especially if you are going to upload it to a GitHub repository. If uploading it to a repository, you should include the file containing your key in your .gitignore.

# %%
url = "https://maps.googleapis.com/maps/api/directions/json"

f = open("./key.json")
key = json.load(f)["key"]

params = {
    "key" : key,
    "origin" : "46.06229485964312,-118.3537494721578",
    "destination" : "45.51812258332594,-122.67900092620407"
}

response = requests.get(url, params = params)
directions = response.json()

# %% [markdown]
# Now that we have the data from the api, we can parse the json object for useful data.

# %%
df_directions = pd.DataFrame(columns = ["distance","direction","duration"])

for step in directions['routes'][0]['legs'][0]['steps']:
    if ("maneuver" in step.keys() ):
        maneuver = step["maneuver"]
    else:
        maneuver = "start"
    df_directions.loc[len(df_directions.index)] = [step["distance"]["text"], maneuver, step["duration"]["text"]]

df_directions
# Out:
#    distance         direction         duration
# 0    282 ft             start            1 min
# 1    0.5 mi        turn-right            1 min
# 2    0.6 mi         turn-left            1 min
# 3    269 ft  roundabout-right            1 min
# 4    0.5 mi  roundabout-right            1 min
# 5   26.8 mi             merge          25 mins
# 6   25.3 mi          straight          27 mins
# 7    9.4 mi         ramp-left           9 mins
# 8    170 mi        ramp-right  2 hours 31 mins
# 9    6.7 mi        keep-right           7 mins
# 10   0.4 mi         ramp-left            1 min
# 11   0.4 mi        keep-right            1 min
# 12   0.3 mi             start            1 min
# 13   354 ft             start            1 min
# 14   0.2 mi         turn-left            1 min
# 15   0.2 mi        turn-right            1 min
# 16   157 ft        turn-right            1 min

# %% [markdown]
# Now we have the directions from Walla Walla to Portland in the format of a datarame, accessed from the Google routes API.

# %% [markdown]
# Recipe two: Scraping data from the web
#
# When data is not availible in an easily downloadable format, you might need to scrape it from a website to access it. Scraping a webpage is a technique which accesses the html script of a webpage and returns it in a formate which you can then parse and create a dataset from. typically, this is done using the beautiful soup package. The beautiful soup package parses the requested html, allowing easy access to the webpage content. Here are the imports required.

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %% [markdown]
# Now, for the purpose of this example I will scrape data from Kevin Pogue's webpage of climbing routes.

# %%
url = 'http://people.whitman.edu/~pogue/climbing/routes.html'
soup = bs(requests.get(url).text, "html.parser")

# %%
locations = soup.find_all('h2')
lists = soup.find_all('ul')
list_elements = soup.find_all('li')

# %% [markdown]
# This part of the process will be unique for any given webpage, and will require some digging through th html to identify exaclty which elements you want to access

# %%
df_routes = pd.DataFrame(columns=['Route','Location','Grade'])

for i in range(len(lists)):
    for child in lists[i].children:
        text = child.text.strip()
        if text != '':
            if ',' not in child.text.strip(): # handle inconsistent grade formatting
                for j in range(len(child.text.strip())):
                    if child.text.strip()[-j] == ' ':
                        route = child.text.strip()[:-(j)].replace(',','')
                        grade = child.text.strip()[-(j):]
                        break
            else:
                route = ''.join(child.text.split(',')[:-1])
                grade = child.text.split(',')[-1]
            df_routes.loc[len(df_routes)] = [route,locations[i].text.strip(),grade.replace('*','')]
df_routes
# Out:
#                      Route              Location   Grade
# 0         Creature Feature   Red River Gorge, KY     5.9
# 1             Pogue Ethics   Red River Gorge, KY   5.10a
# 2        Lord of the Flies   Red River Gorge, KY     5.8
# 3    Face up to that Crack   Red River Gorge, KY     5.7
# 4               Exhibition   Red River Gorge, KY     5.9
# ..                     ...                   ...     ...
# 104        Arterial Bypass  Frenchman Coulee, WA     5.8
# 105          Deadbeat Dads  Frenchman Coulee, WA     5.7
# 106        Working Mothers  Frenchman Coulee, WA   5.10a
# 107         Pigs in Heaven     Devils Canyon, WA     5.8
# 108       I Can't Remember     Devils Canyon, WA     5.9
#
# [109 rows x 3 columns]

# %% [markdown]
# Recipe three: Working with location data
#
# Location data is pretty unique in terms of types of data. It is typically given in the form of latitude and longitude associated with some other identifying information. Location data can lend to some very insightful and engaging visualizations if used well.

# %% [markdown]
# For this demo I will be working with a dataset and creating a map-based visualization from that data's location information.

# %%
import pandas as pd
import folium as fl

# %%
df = pd.read_csv('./Central-East Cascades, Wenatchee, & Leavenworth.csv')
df
# Out:
#                     Route                                           Location  \
# 0              The Pillar  West Side > Orchard Rock > Peshastin Pinnacles...
# 1                Tortoise  Upper Martian Slab > Peshastin Pinnacles State...
# 2              Grey Whale  Upper Martian Slab > Peshastin Pinnacles State...
# 3          Humpback Whale  Upper Martian Slab > Peshastin Pinnacles State...
# 4            Baseball Nut  Upper Martian Slab > Peshastin Pinnacles State...
# ..                    ...                                                ...
# 513    The Crystal Method  (d) Mod Squad > Nason Ridge > Leavenworth > Ce...
# 514              Beachin’  Bimbo Beach Bolted Bluffs > East Wenatchee > W...
# 515             Dyno-mite  Bimbo Beach Bolted Bluffs > East Wenatchee > W...
# 516         Billy the kid  Bimbo Beach Bolted Bluffs > East Wenatchee > W...
# 517  Sharky Determination  Chumstick Snag > Central-East Cascades, Wenatc...
#
#                                                    URL  Avg Stars  Your Stars  \
# 0    https://www.mountainproject.com/route/10587544...        1.5          -1
# 1    https://www.mountainproject.com/route/11026013...        2.0          -1
# 2    https://www.mountainproject.com/route/10587701...        2.0          -1
# 3    https://www.mountainproject.com/route/11026014...        1.0          -1
# 4    https://www.mountainproject.com/route/10587700...        1.2          -1
# ..                                                 ...        ...         ...
# 513  https://www.mountainproject.com/route/11672655...        2.6          -1
# 514  https://www.mountainproject.com/route/12080265...        2.0          -1
# 515  https://www.mountainproject.com/route/12080262...        2.0          -1
# 516  https://www.mountainproject.com/route/12080272...        2.0          -1
# 517  https://www.mountainproject.com/route/12280811...        2.0          -1
#
#     Route Type   Rating  Pitches  Length  Area Latitude  Area Longitude
# 0        Sport  5.10d R        1     NaN       47.54052      -120.51925
# 1        Sport      5.8        1    70.0       47.54188      -120.52071
# 2        Sport     5.8+        1     NaN       47.54188      -120.52071
# 3        Sport     5.8+        1    70.0       47.54188      -120.52071
# 4        Sport      5.9        1     NaN       47.54188      -120.52071
# ..         ...      ...      ...     ...            ...             ...
# 513      Sport    5.10d        1    60.0       47.78012      -120.83215
# 514  Sport, TR      5.7        1    40.0       47.46648      -120.31350
# 515  Sport, TR      5.8        1    40.0       47.46648      -120.31350
# 516      Sport      5.8        1    40.0       47.46648      -120.31350
# 517  Sport, TR    5.10d        1    80.0       47.65506      -120.65432
#
# [518 rows x 11 columns]

# %% [markdown]
# This dataset includes the longitude and latitude of each route, along with the location. Now the map that we will plot the locations on. It will be centered at the coordinates: 47.589588804778415, -120.64361235785819, a location near Leavenworth.

# %%
m = fl.Map(location=[47.589588804778415, -120.64361235785819],
                   zoom_start=10, control_scale=True)

# %%
m # map before any points are added.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a2a3e5ebe10db77a88bb142a31f6fca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a2a3e5ebe10db77a88bb142a31f6fca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a2a3e5ebe10db77a88bb142a31f6fca = L.map(
#                 &quot;map_1a2a3e5ebe10db77a88bb142a31f6fca&quot;,
#                 {
#                     center: [47.589588804778415, -120.64361235785819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#
#
#
#             var tile_layer_ad5ab0a3c4e91d836f1460d976b84ed0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ad5ab0a3c4e91d836f1460d976b84ed0.addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now we can iterate through the dataframe to add each point to the map.

# %%
for index, row in df.iterrows():
    fl.Marker(location = [row['Area Latitude'], row['Area Longitude']], popup = row['Route']).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a2a3e5ebe10db77a88bb142a31f6fca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a2a3e5ebe10db77a88bb142a31f6fca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a2a3e5ebe10db77a88bb142a31f6fca = L.map(
#                 &quot;map_1a2a3e5ebe10db77a88bb142a31f6fca&quot;,
#                 {
#                     center: [47.589588804778415, -120.64361235785819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#
#
#
#             var tile_layer_ad5ab0a3c4e91d836f1460d976b84ed0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ad5ab0a3c4e91d836f1460d976b84ed0.addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#             var marker_2651f38bcfc0040c7be7c61609ac3818 = L.marker(
#                 [47.54052, -120.51925],
#                 {}
#             ).addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#         var popup_c962b860a437d9b56ff194b1d40ea376 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_724363d6b7d8b3fb8fb27693ab8638b9 = $(`&lt;div id=&quot;html_724363d6b7d8b3fb8fb27693ab8638b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Pillar&lt;/div&gt;`)[0];
#                 popup_c962b860a437d9b56ff194b1d40ea376.setContent(html_724363d6b7d8b3fb8fb27693ab8638b9);
#
#
#
#         marker_2651f38bcfc0040c7be7c61609ac3818.bindPopup(popup_c962b860a437d9b56ff194b1d40ea376)
#         ;
#
#
#
#
#             var marker_8d2bb42100b6cd9ba688072a2021b4cd = L.marker(
#                 [47.54188, -120.52071],
#                 {}
#             ).addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#         var popup_3332fafdc170766e9dc7286819b3671e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_618bf57be2a0973392f7b9c95ca54cda = $(`&lt;div id=&quot;html_618bf57be2a0973392f7b9c95ca54cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tortoise&lt;/div&gt;`)[0];
#                 popup_3332fafdc170766e9dc7286819b3671e.setContent(html_618bf57be2a0973392f7b9c95ca54cda);
#
#
#
#         marker_8d2bb42100b6cd9ba688072a2021b4cd.bindPopup(popup_3332fafdc170766e9dc7286819b3671e)
#         ;
#
#
#
#
#             var marker_1df97340b2a35a8e1d110e86325a6745 = L.marker(
#                 [47.54188, -120.52071],
#                 {}
#             ).addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#         var popup_d17a44e81e4eb6f57f91a46c00572cb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6cf6311ee4e01fdd512ac0e5cfcef9a4 = $(`&lt;div id=&quot;html_6cf6311ee4e01fdd512ac0e5cfcef9a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Grey Whale&lt;/div&gt;`)[0];
#                 popup_d17a44e81e4eb6f57f91a46c00572cb2.setContent(html_6cf6311ee4e01fdd512ac0e5cfcef9a4);
#
#
#
#         marker_1df97340b2a35a8e1d110e86325a6745.bindPopup(popup_d17a44e81e4eb6f57f91a46c00572cb2)
#         ;
#
#
#
#
#             var marker_68effd2ff4da789f7295921b275f5ed8 = L.marker(
#                 [47.54188, -120.52071],
#                 {}
#             ).addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#         var popup_2ea1caddd8352da604bb75ddcc75efaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ead86c2c59cf98e752222e6ee5b191e6 = $(`&lt;div id=&quot;html_ead86c2c59cf98e752222e6ee5b191e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Humpback Whale&lt;/div&gt;`)[0];
#                 popup_2ea1caddd8352da604bb75ddcc75efaf.setContent(html_ead86c2c59cf98e752222e6ee5b191e6);
#
#
#
#         marker_68effd2ff4da789f7295921b275f5ed8.bindPopup(popup_2ea1caddd8352da604bb75ddcc75efaf)
#         ;
#
#
#
#
#             var marker_c2aab20212971a54b582130b648b45b1 = L.marker(
#                 [47.54188, -120.52071],
#                 {}
#             ).addTo(map_1a2a3e5ebe10db77a88bb142a31f6fca);
#
#
#         var popup_8c1b41946513233d0654c38ec63fb2f7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7bd9ace08dc8d1dc43ebc6196f98ceda = $(`&lt;div id=&quot;html_7bd9ace08dc8d1dc43ebc6196f98ceda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baseball Nut&lt;/div&gt;`)[0];
#                 popup_8c1b41946513233d0654c38ec63fb2f7.setContent(html_7bd9ace08dc8d1dc43ebc6196f98ceda);
#
#
#
#         marker_c2aab20212971a54b582130b648b45b1.bindPopup(popup_8c1b41946513233d0654c38ec63fb2f7)

# %% [markdown]
# Now thats a lot of points, if we want a visualizaiton which is a little more readable, we can group the points using a density based grouping algorithm. Plotting this on the map will give a better idea of the distinct areas represented by the points.

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

coords = []
for index, row in df.iterrows():
    coords.append((row['Area Latitude'], row['Area Longitude']))

scaler = StandardScaler()
scaled_coords = scaler.fit_transform(coords)

epsilon = 0.2
min_samples = 1

dbscan = DBSCAN(eps=epsilon, min_samples=min_samples)
clusters = dbscan.fit_predict(scaled_coords)

df['cluster'] = clusters
df_clustered = df.groupby(by=df['cluster']).agg({
    'Area Latitude':'mean',
    'Area Longitude':'mean',
    'Route':'sum',
    'Avg Stars': 'mean'
})


df_clustered['cluster'] = df_clustered.index

# %% [markdown]
# Now, I have clusters associated with the individual routes, and I can plot the clusters on the map to get an idea of where the densities of routes are.

# %%
m1 = fl.Map(location=[47.589588804778415, -120.64361235785819],
                   zoom_start=10, control_scale=True)

for index, row in df_clustered.iterrows():
    fl.Marker(location = [row['Area Latitude'], row['Area Longitude']], popup=row['Route']).add_to(m1)
for index, row in df.iterrows():
    fl.Circle(location = [row['Area Latitude'], row['Area Longitude']], popup=row['Route']).add_to(m1)

# %%
m1 # map with both route data and cluster data.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f319b6273a2c8d490c2a66a534b29ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f319b6273a2c8d490c2a66a534b29ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f319b6273a2c8d490c2a66a534b29ce = L.map(
#                 &quot;map_4f319b6273a2c8d490c2a66a534b29ce&quot;,
#                 {
#                     center: [47.589588804778415, -120.64361235785819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#
#
#
#             var tile_layer_fbca79319b86fdeabcd77f0a089f1472 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fbca79319b86fdeabcd77f0a089f1472.addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#             var marker_9f1a99dda844c0ac8219663531a50527 = L.marker(
#                 [47.5424764, -120.52076919999999],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_5d6e194972c3344f4d209c90ea91d478 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_424fbe787df1871e03d295a7faa8ad0c = $(`&lt;div id=&quot;html_424fbe787df1871e03d295a7faa8ad0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The PillarTortoiseGrey WhaleHumpback WhaleBaseball NutHarpoonistPotholes Direct DirectWashboardDr. LeakeyBooby VintonSunsetNational VelvetTippy ToesVelvet ElvisWest FaceWest Face DirectShady LaneMexican FiestaSlakin&#x27;Slender ThreadFakin&#x27; ItCajun QueenWindward DirectGalileoMars Rover&lt;/div&gt;`)[0];
#                 popup_5d6e194972c3344f4d209c90ea91d478.setContent(html_424fbe787df1871e03d295a7faa8ad0c);
#
#
#
#         marker_9f1a99dda844c0ac8219663531a50527.bindPopup(popup_5d6e194972c3344f4d209c90ea91d478)
#         ;
#
#
#
#
#             var marker_76c16f9ec4153ad58ef7206ea0275e17 = L.marker(
#                 [47.73898, -120.87395],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_58dbeff9a444bc1530932d6ac0730302 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54cd192c6938537feec4343badf929ad = $(`&lt;div id=&quot;html_54cd192c6938537feec4343badf929ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No Knees, No Trees3 Goats, 2 Kegs and 1 Pig&lt;/div&gt;`)[0];
#                 popup_58dbeff9a444bc1530932d6ac0730302.setContent(html_54cd192c6938537feec4343badf929ad);
#
#
#
#         marker_76c16f9ec4153ad58ef7206ea0275e17.bindPopup(popup_58dbeff9a444bc1530932d6ac0730302)
#         ;
#
#
#
#
#             var marker_cca4653f58ad41c11ab89e6d3cca098f = L.marker(
#                 [47.49184, -120.81797],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_110aafe2c78fcea383e05d85cf986cd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b92f84b4a8b3925c675ecfb788c99478 = $(`&lt;div id=&quot;html_b92f84b4a8b3925c675ecfb788c99478&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Let it Burn&lt;/div&gt;`)[0];
#                 popup_110aafe2c78fcea383e05d85cf986cd7.setContent(html_b92f84b4a8b3925c675ecfb788c99478);
#
#
#
#         marker_cca4653f58ad41c11ab89e6d3cca098f.bindPopup(popup_110aafe2c78fcea383e05d85cf986cd7)
#         ;
#
#
#
#
#             var marker_aa13ff56b46f0ff14143cc4aaa047394 = L.marker(
#                 [47.48206, -120.78123],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_5aeef2be42e6bbfb10d8d81d5839380c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86c49ac2d52f5c9c60ce4841dd54c274 = $(`&lt;div id=&quot;html_86c49ac2d52f5c9c60ce4841dd54c274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Smears, Jugs, and Rock &amp; Roll&lt;/div&gt;`)[0];
#                 popup_5aeef2be42e6bbfb10d8d81d5839380c.setContent(html_86c49ac2d52f5c9c60ce4841dd54c274);
#
#
#
#         marker_aa13ff56b46f0ff14143cc4aaa047394.bindPopup(popup_5aeef2be42e6bbfb10d8d81d5839380c)
#         ;
#
#
#
#
#             var marker_f6e654fe55d94363ba7d4cc6ed5aa7a8 = L.marker(
#                 [47.46673, -120.94115],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_8794910c529a7e5a9bc48264b2873280 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20e53862452704bb57bd17807cff7ab0 = $(`&lt;div id=&quot;html_20e5386

# %% [markdown]
# Now we have a much more informative visualization of the area clusters and individual routes in this dataset. These techniques can be applied to many types of location data and clustering can be applied to many types of two-dimensional data. Another way to represent density like this on a map would be with a heatmap rather than individual points on a map. For the heatmap, we will need to create a heatmap layer to go on the map.

# %% [markdown]
# First we create a list of the coordinates we want to show on the heatmap, then simply pass it into the heatmap layer function from folium.

# %%
from folium.plugins import HeatMap

coords = [[row['Area Latitude'], row['Area Longitude']] for index, row in df.iterrows()]
heatmap = HeatMap(coords)
heatmap.add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f319b6273a2c8d490c2a66a534b29ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f319b6273a2c8d490c2a66a534b29ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f319b6273a2c8d490c2a66a534b29ce = L.map(
#                 &quot;map_4f319b6273a2c8d490c2a66a534b29ce&quot;,
#                 {
#                     center: [47.589588804778415, -120.64361235785819],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#
#
#
#             var tile_layer_fbca79319b86fdeabcd77f0a089f1472 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_fbca79319b86fdeabcd77f0a089f1472.addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#             var marker_9f1a99dda844c0ac8219663531a50527 = L.marker(
#                 [47.5424764, -120.52076919999999],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_5d6e194972c3344f4d209c90ea91d478 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_424fbe787df1871e03d295a7faa8ad0c = $(`&lt;div id=&quot;html_424fbe787df1871e03d295a7faa8ad0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The PillarTortoiseGrey WhaleHumpback WhaleBaseball NutHarpoonistPotholes Direct DirectWashboardDr. LeakeyBooby VintonSunsetNational VelvetTippy ToesVelvet ElvisWest FaceWest Face DirectShady LaneMexican FiestaSlakin&#x27;Slender ThreadFakin&#x27; ItCajun QueenWindward DirectGalileoMars Rover&lt;/div&gt;`)[0];
#                 popup_5d6e194972c3344f4d209c90ea91d478.setContent(html_424fbe787df1871e03d295a7faa8ad0c);
#
#
#
#         marker_9f1a99dda844c0ac8219663531a50527.bindPopup(popup_5d6e194972c3344f4d209c90ea91d478)
#         ;
#
#
#
#
#             var marker_76c16f9ec4153ad58ef7206ea0275e17 = L.marker(
#                 [47.73898, -120.87395],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_58dbeff9a444bc1530932d6ac0730302 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54cd192c6938537feec4343badf929ad = $(`&lt;div id=&quot;html_54cd192c6938537feec4343badf929ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;No Knees, No Trees3 Goats, 2 Kegs and 1 Pig&lt;/div&gt;`)[0];
#                 popup_58dbeff9a444bc1530932d6ac0730302.setContent(html_54cd192c6938537feec4343badf929ad);
#
#
#
#         marker_76c16f9ec4153ad58ef7206ea0275e17.bindPopup(popup_58dbeff9a444bc1530932d6ac0730302)
#         ;
#
#
#
#
#             var marker_cca4653f58ad41c11ab89e6d3cca098f = L.marker(
#                 [47.49184, -120.81797],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_110aafe2c78fcea383e05d85cf986cd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b92f84b4a8b3925c675ecfb788c99478 = $(`&lt;div id=&quot;html_b92f84b4a8b3925c675ecfb788c99478&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Let it Burn&lt;/div&gt;`)[0];
#                 popup_110aafe2c78fcea383e05d85cf986cd7.setContent(html_b92f84b4a8b3925c675ecfb788c99478);
#
#
#
#         marker_cca4653f58ad41c11ab89e6d3cca098f.bindPopup(popup_110aafe2c78fcea383e05d85cf986cd7)
#         ;
#
#
#
#
#             var marker_aa13ff56b46f0ff14143cc4aaa047394 = L.marker(
#                 [47.48206, -120.78123],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_5aeef2be42e6bbfb10d8d81d5839380c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86c49ac2d52f5c9c60ce4841dd54c274 = $(`&lt;div id=&quot;html_86c49ac2d52f5c9c60ce4841dd54c274&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Smears, Jugs, and Rock &amp; Roll&lt;/div&gt;`)[0];
#                 popup_5aeef2be42e6bbfb10d8d81d5839380c.setContent(html_86c49ac2d52f5c9c60ce4841dd54c274);
#
#
#
#         marker_aa13ff56b46f0ff14143cc4aaa047394.bindPopup(popup_5aeef2be42e6bbfb10d8d81d5839380c)
#         ;
#
#
#
#
#             var marker_f6e654fe55d94363ba7d4cc6ed5aa7a8 = L.marker(
#                 [47.46673, -120.94115],
#                 {}
#             ).addTo(map_4f319b6273a2c8d490c2a66a534b29ce);
#
#
#         var popup_8794910c529a7e5a9bc48264b2873280 = L.popup({&quot;max

# %% [markdown]
# This map shows the same density information and we can gather that there are two pretty distinct high-density areas on the map, similarly to the density based clustering.

# %% [markdown]
# Recipe Four: Data manipulation for graphing

# %% [markdown]
# Often the way your data is organized for your inital analysis is not that conducive to a good visual representation through the graphing tools availible in python. Pandas provides some good tools reformat dataframes for visualization which I will show through this example from project 8, which graphs two different datasets on top of each other, and uses the two most useful tools for refomatting data in pandas: groupby and melt.

# %% [markdown]
# First some wrangling of the data so it has the data we want to graph.

# %%
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("Timestamps")
df2 = pd.read_csv("angel_timestamps.csv")

# %%
df1["month"] = pd.DatetimeIndex(df1['TimeStamp']).month
df2["month"] = pd.DatetimeIndex(df2["Start Time"]).month

# %%
df1_by_month = df1.groupby("month").count()
df2_by_month = df2.groupby("month").count()

# %% [markdown]
# Here I merge the two datasets together for the graph.

# %%
merged = df1_by_month.join(df2_by_month, how="inner", on="month", lsuffix="x", rsuffix="y")

# %% [markdown]
# Rename columns for for the graph.

# %%
merged["Oliver Count"] = merged["TimeStamp"]
merged["Angel Count"] = merged["Start Time"]

# %% [markdown]
# Drop redundant columns.

# %%
merged.drop(["TimeStamp", "Unnamed: 0x", "Unnamed: 0y", "Start Time"], axis=1)
merged['month'] = merged.index

# %% [markdown]
# Here I use the melt function of pandas to set the value and ID columns for the graph.

# %%
melted = pd.melt(merged, id_vars="month", value_vars=["Oliver Count", "Angel Count"], value_name="count")

# %%
melted['person'] = melted['variable']
melted.drop(['variable'], axis = 1)# It looks a lot different from the original dataset.

# %%
sns.barplot(data = melted, x = "month", y = "count", hue = "person")

# %% [markdown]
# Now we have a graph comparing the two datasets. The melt function was very useful in seperating the data in a way which could differentiate the person, month, and count of each row. The melt operator is very useful when your dataframe is not in a format which the graph can interpret easily, not just for bar graphs.
